# %%
from jupyslides import jupyslides
slides_path = 'Dickinson_Sample_Slides'
import glob
img_list = glob.glob(slides_path + '/*.png')
img_list.sort()
from IPython.display import Image
for img in img_list:
    display(Image(filename=img, width=800, height=400))
